# %%
# %matplotlib inline
import pandas as pd
import quandl as q
df = q.get("WIKI/GOOGL")
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# ...

# %%
df.sort_values('High').head()
# Out:
#               Open    High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2004-09-03  100.95  101.74   99.32  100.01   5152400.0          0.0
# 2004-09-07  101.01  102.00   99.61  101.58   5847500.0          0.0
# 2004-09-02   99.09  102.37   98.94  101.51  15118600.0          0.0
# 2004-09-09  102.50  102.71  101.00  102.31   4061700.0          0.0
# 2004-09-01  102.70  102.97   99.67  100.25   9138200.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-09-03          1.0  50.631294  51.027517  49.813770   50.159839
# 2004-09-07          1.0  50.661387  51.157920  49.959219   50.947269
# 2004-09-02          1.0  49.698414  51.343492  49.623182   50.912161
# 2004-09-09          1.0  51.408694  51.514019  50.656371   51.313400
# 2004-09-01          1.0  51.509003  51.644421  49.989312   50.280210
#
#             Adj. Volume
# Date
# 2004-09-03    5152400.0
# 2004-09-07    5847500.0
# 2004-09-02   15118600.0
# ...

# %%
pf = df[['Open','High','Low','Close']]
pf.index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2a6b6b339f6d> in <module>
#       1 pf = df[['Open','High','Low','Close']]
# ----> 2 pf.index(inplace=True)
#
# TypeError: 'DatetimeIndex' object is not callable

# %%
count = df['High'].value_counts().head()

# %%
count.plot(kind='bar')
